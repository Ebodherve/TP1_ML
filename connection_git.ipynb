# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
# %cd TP_MACHINE_LEARNING/
# Out:
# /content/drive/MyDrive/Github/TP_MACHINE_LEARNING

# %%
# !ls
# Out:
#  connection_git.ipynb   ML_TP1.ipynb  "tutoriel_d'apprentissage.ipynb"

# %%
# !git checkout tsanga
# Out:
# Switched to branch 'tsanga'

# %%
username = "Ebodherve"
repository = "TP1_ML"
git_token = "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"
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# Out:
# fatal: remote origin already exists.

# %%
# !git pull origin tsanga
# Out:
# fatal: Couldn't find remote ref tsanga
