# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
# %cd TP_MACHINE_LEARNING/
# Out:
# /content/drive/MyDrive/Github/TP_MACHINE_LEARNING

# %%
# !ls
# Out:
#  connection_git.ipynb   ML_TP1.ipynb  "tutoriel_d'apprentissage.ipynb"

# %%
# !git checkout tsanga
# Out:
# Switched to branch 'tsanga'

# %%
username = "Ebodherve"
repository = "TP1_ML"
git_token = "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"
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git

# %%
# !git config --global user.email "tsangaebodepython@gmail.com"
# !git config --global user.name "Ebodherve"

# %%
# !git push origin tsanga
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 944.66 KiB | 10.38 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'tsanga' on GitHub by visiting:
# remote:      https://github.com/Ebodherve/TP1_ML/pull/new/tsanga
# remote:
# To https://github.com/Ebodherve/TP1_ML.git
#  * [new branch]      tsanga -> tsanga

# %%
# !git checkout main
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	connection_git.ipynb
# Please commit your changes or stash them before you switch branches.
# Aborting
